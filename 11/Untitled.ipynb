# %%
import pandas as pd
import scipy
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time
from NeuralNetwork import *
data = pd.read_csv('DATA.csv')
X_train, X_test, y_train, y_test = train_test_split(data[['x1','x2']], data[['y']], test_size=0.255, random_state=1990243)

X_train = X_train.to_numpy()
X_test = X_test.to_numpy()
y_tr = y_train.to_numpy()
y_te = y_test.to_numpy()

# %%
## grid search question 11

rho_list = np.arange(0.0001, 0.0009, 0.0002)
sigma_list = np.arange(0.5, 2, 0.25)
N_list = (2, 4, 8, 16, 32)
opt_params = grid_search(X_train, X_test, y_tr, y_test, 1,rho_list, sigma_list, N_list, 'CG')

# %%
print(opt_params[0])
# Out:
# (0.0007000000000000001, 1.5, 32)

# %%
hyperparam_err = opt_params[1]
hyperparam_err.shape
plt.plot(rho_list, hyperparam_err[:, 4, 4])

# %%
plt.plot(sigma_list, hyperparam_err[3, :, 4])

# %%
plt.plot(N_list, hyperparam_err[3, 4, :])
