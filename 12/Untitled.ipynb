# %%
import pandas as pd
import scipy
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time
from Optimizer import *
data = pd.read_csv('DATA.csv')
X_train, X_test, y_train, y_test = train_test_split(data[['x1','x2']], data[['y']], test_size=0.255, random_state=1990243)

X_train = X_train.to_numpy()
X_test = X_test.to_numpy()
y_tr = y_train.to_numpy()
y_te = y_test.to_numpy()
# Out:
# Loss in the beginning: 1.5603477859263792
# Loss after convex optim: 0.13999509797495463
# Loss after non convex optim: 0.08438812353166679
# Loss after convex optim: 0.03296990601203138
# Loss after non convex optim: 0.08039176238610644
# Loss after convex optim: 0.027010188734328
# Loss after non convex optim: 0.09429836121296574
#      fun: 0.09429836121296574
#      jac: array([-1.50983431e-03, -9.85269561e-04, -7.24421302e-04, -3.69365925e-03,
#         1.55434775e-03, -6.88932179e-04,  2.20550054e-03,  3.31183754e-03,
#         9.31129161e-04,  2.67035207e-03, -6.32686124e-05,  1.18169029e-03,
#        -2.07524746e-03, -1.02942742e-03, -4.00332358e-04, -3.03782066e-04,
#         5.85648277e-04,  1.12562318e-04, -8.69307714e-04, -3.21787030e-05,
#        -3.58063369e-03,  3.14754366e-03,  2.01732692e-04, -2.56328048e-02,
#         1.06819994e-03,  2.30455804e-03,  6.66785041e-04,  1.39721024e-03,
#        -3.12881512e-03,  7.11697036e-04,  3.73931704e-03,  5.21546290e-03,
# ...

# %%
## grid search question 12

rho_list = np.arange(0.0005, 0.0015, 0.0002)
sigma_list = np.arange(1, 3, 0.25)
N_list = (2, 4, 8, 16, 32)
opt_params = grid_search(X_train, X_test, y_tr, y_test, 1,rho_list, sigma_list, N_list, 'CG')

# %%
print(opt_params[0])

hyperparam_err = opt_params[1]
hyperparam_err.shape
plt.plot(rho_list, hyperparam_err[:, 0, 4])
# Out:
# (0.0009, 1.0, 32)

# %%
plt.plot(sigma_list, hyperparam_err[3, :, 4])

# %%
plt.plot(N_list, hyperparam_err[3, 0, :])
